# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
SA = pd.read_csv("C:/Users/Lenovo/Downloads/matches.csv") #importing the data

# %%
SA.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
pd.set_option('display.max_columns', None) # to display maximum/all columns

# %%
SA.head() #None means all value if we need to show only 1 or 2 column then weneed to mention accordingly
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
SA.columns #To see what are the columns available in your data
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
SA.dtypes #Lets check the data types of all the columns
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
#lets get the numerical columns only
SA.select_dtypes(include=np.number)
# Out:
#         id  season  dl_applied  win_by_runs  win_by_wickets
# 0        1    2017           0           35               0
# 1        2    2017           0            0               7
# 2        3    2017           0            0              10
# 3        4    2017           0            0               6
# 4        5    2017           0           15               0
# ..     ...     ...         ...          ...             ...
# 751  11347    2019           0            0               9
# 752  11412    2019           0            0               6
# 753  11413    2019           0            0               2
# 754  11414    2019           0            0               6
# 755  11415    2019           0            1               0
#
# [756 rows x 5 columns]

# %%
SA.select_dtypes(include=np.number).columns #to see which are the columns having numeric values only
# Out:
# Index(['id', 'season', 'dl_applied', 'win_by_runs', 'win_by_wickets'], dtype='object')

# %%
##lets get the categorical columns only
SA.select_dtypes(exclude=np.number)
# Out:
#               city        date                        team1  \
# 0        Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1             Pune  2017-04-06               Mumbai Indians
# 2           Rajkot  2017-04-07                Gujarat Lions
# 3           Indore  2017-04-08       Rising Pune Supergiant
# 4        Bangalore  2017-04-08  Royal Challengers Bangalore
# ..             ...         ...                          ...
# 751         Mumbai    05/05/19        Kolkata Knight Riders
# 752        Chennai    07/05/19          Chennai Super Kings
# 753  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  Visakhapatnam    10/05/19               Delhi Capitals
# 755      Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
SA.select_dtypes(exclude=np.number).columns #to see which are the columns having categorical values only
# Out:
# Index(['city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision',
#        'result', 'winner', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
SA.shape # to see how many rowa and columns are there in the Data
# Out:
# (756, 18)

# %%
#Let see the info of the dataset.
SA.info() #column namse, number of non-null rows in each column, data type of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
#lets display the important statistics of the dataset(numerical columns)
SA.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
SA.isnull().sum() # to check null values
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
SA.isna().sum() #same as above
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
SA[SA['winner'].isna()] # checking the null value of a particular column
# Out:
#         id  season       city        date                        team1  \
# 300    301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545    546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570    571    2015  Bangalore  2015-05-17             Delhi Daredevils
# 744  11340    2019  Bengaluru    30/04/19  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 744             Rajasthan Royals             Rajasthan Royals         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# ...

# %%
# let see the distribution of datapoints in each numerical column
SA.hist(bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'season'}>],
#        [<AxesSubplot:title={'center':'dl_applied'}>,
#         <AxesSubplot:title={'center':'win_by_runs'}>],
#        [<AxesSubplot:title={'center':'win_by_wickets'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
SA.hist(bins=60, figsize=(20,10)) # same as above but aligning the figur size
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'season'}>],
#        [<AxesSubplot:title={'center':'dl_applied'}>,
#         <AxesSubplot:title={'center':'win_by_runs'}>],
#        [<AxesSubplot:title={'center':'win_by_wickets'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
SA.head() #againg checking the headings
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
SA["city"].nunique() # checking the unique "count" values for a particular column
# Out:
# 32

# %%
SA["city"].unique() # checking the column values which is having unique values
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
SA["city"].value_counts() #checking the "count" of unique values for a particular column
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
SA.nunique() #checking the unique value for all the columns
# Out:
# id                 756
# season              12
# city                32
# date               546
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# result               3
# dl_applied           2
# winner              15
# win_by_runs         89
# win_by_wickets      11
# player_of_match    226
# venue               41
# umpire1             61
# umpire2             65
# umpire3             25
# dtype: int64

# %%
SA['city'].value_counts().plot(kind='bar', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
SA[SA['season'] == 2017]
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
SA[SA['win_by_runs'] > 35]
# Out:
#         id  season       city        date                   team1  \
# 8        9    2017       Pune  2017-04-11        Delhi Daredevils
# 14      15    2017      Delhi  2017-04-15        Delhi Daredevils
# 26      27    2017    Kolkata  2017-04-23   Kolkata Knight Riders
# 32      33    2017       Pune  2017-04-29  Rising Pune Supergiant
# 35      36    2017  Hyderabad  2017-04-30     Sunrisers Hyderabad
# ..     ...     ...        ...         ...                     ...
# 725  11321    2019  Hyderabad    14/04/19          Delhi Capitals
# 729  11325    2019      Delhi    18/04/19          Mumbai Indians
# 739  11335    2019    Chennai    26/04/19          Mumbai Indians
# 743  11339    2019  Hyderabad    29/04/19     Sunrisers Hyderabad
# 745  11341    2019    Chennai    01/05/19     Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 8         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %% [markdown]
# # Thank You
